# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd
import seaborn as sns

# 設定 data_path
dir_data = './Data/application_train.csv'

# %%
app_train = pd.read_csv('Data/application_train.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
#
# #### Eg
# 計算任意欄位的平均數及標準差
# 畫出任意欄位的直方圖
# ### Hints:
# Descriptive Statistics For pandas Dataframe
# pandas 中的繪圖函數

# %%
app_train.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
app_clean = app_train.dropna()
app_clean.head()
# Out:
#      SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 71       100083       0         Cash loans           M            Y
# 124      100145       0         Cash loans           F            Y
# 152      100179       0         Cash loans           F            Y
# 161      100190       0         Cash loans           M            Y
# 255      100295       1         Cash loans           M            Y
#
#     FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 71                Y             0          103500.0    573628.5      24435.0
# 124               Y             1          202500.0    260725.5      16789.5
# 152               N             0          202500.0    675000.0      53329.5
# 161               N             0          162000.0    263686.5      24781.5
# 255               N             1          225000.0   1019205.0      31032.0
#
#                 ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
anual = app_clean['AMT_ANNUITY'].head(100)
credit = app_clean['AMT_CREDIT'].head(100)

plt.scatter(anual,credit)

# %%
app_clean.AMT_INCOME_TOTAL.hist(bins = 200)
plt.xlim(xmin = 0,xmax = 1000000)
# Out:
# (0, 1000000)

# %%
def filter(gend , values):
    code_list = ['AMT_INCOME_TOTAL' , 'AMT_CREDIT','AMT_ANNUITY']
    lists =[]
    for i in code_list:
        a = gender.loc[gend , i][values]
        lists.append(a)
    return lists

# %%
male_mean = filter('M' , 'mean')
female_mean = filter('F' , 'mean')
male_std = filter('M' , 'std')
female_std = filter('F' , 'std')

# %%
N = len(code_list)
ind = np.arange(N)
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, male_mean, width, yerr=male_std,color='SkyBlue', label='Men')
rects2 = ax.bar(ind + width/2, female_mean, width, yerr=female_std,color='IndianRed', label='Women')

plt.xticks(ind,code_list)

plt.legend()
